# %%
import pandas as pd
import numpy as np
from citipy import citipy

# %%
#getting coordinates by using random numbers between -90,90 and -180,180

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.

x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
#Shows how the data are printed

for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
#we have a list named coordinates where random coordinates are put

coordinates = list(lat_lngs)

#checking how many coordinates we get - 1500
len(coordinates)
# Out:
# 1500

# %%
# Use the citipy module to determine city based on latitude and longitude.
#the module check if there is any city nearby 

from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
#if there is no city nearby the coordinate is dropped

for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# rikitea pf
# klaksvik fo
# bejar es
# amderma ru
# kaitangata nz
# mataura pf
# touros br
# new norfolk au
# vostok ru
# rikitea pf
# hermanus za
# selu in
# hobart au
# punta arenas cl
# port hardy ca
# port alfred za
# jalu ly
# palanpur in
# ancud cl
# dahra sn
# chenzhou cn
# wilmington us
# puerto ayora ec
# constantine dz
# beloha mg
# manali in
# galle lk
# albany au
# chuy uy
# rikitea pf
# lavrentiya ru
# hilo us
# labutta mm
# faanui pf
# bambous virieux mu
# ushuaia ar
# isangel vu
# aksarka ru
# punta arenas cl
# cullen gb
# barrow us
# mataura pf
# saskylakh ru
# rikitea pf
# rikitea pf
# dryden ca
# dzhusaly kz
# turukhansk ru
# makakilo city us
# adrar dz
# albany au
# ughelli ng
# heze cn
# pinega ru
# yellowknife ca
# new norfolk au
# golfito cr
# kavieng pg
# gallup us
# drayton valley ca
# horta pt
# saldanha za
# toliary mg
# airai pw
# longyearbyen sj
# ahipara nz
# fortuna us
# bredasdorp za
# batagay-alyta ru
# port elizabeth za
# hobart au
# bathsheba bb
# ...

# %%
# Create a list for holding the cities. so if there is no city it will not show in the list 
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
#so the number of entries was decreased from 1500 to ~500
len(cities)
# Out:
# 617

# %%
import requests
requests.__version__
# Out:
# '2.22.0'

# %%
# Import the requests library.
import requests

# Import the API key.
#I got a separate python program named config. this command request accessing the program and getting 
#"weather_api_key" variable which has my key

from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0fed1d27c890bee23d79b7e2c72378ec

# %%
# Test: Create an endpoint URL for a city - the address from which we will retreive data
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0fed1d27c890bee23d79b7e2c72378ec&q=Boston

# %%
# Test: Make a 'Get' request for the city weather. Response 200, means address exist
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Test: Create an endpoint URL for a city that doesn't exist. 404 means the address doesn't exist or no access
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Test: Create an endpoint URL for a city using JSON. JSON will always return the status code 200 if exist
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
#Test: Get the text of the 'Get' request. We getting a dictionary with keys: "cord","weather" etc. and nested dictionary as value
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"base":"stations","main":{"temp":35.42,"feels_like":27.23,"temp_min":28.99,"temp_max":41,"pressure":1019,"humidity":55},"visibility":16093,"wind":{"speed":5.82},"clouds":{"all":1},"dt":1582508508,"sys":{"type":1,"id":4210,"country":"US","sunrise":1582457403,"sunset":1582496737},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 35.42,
#   'feels_like': 27.23,
#   'temp_min': 28.99,
#   'temp_max': 41,
#   'pressure': 1019,
#   'humidity': 55},
#  'visibility': 16093,
#  'wind': {'speed': 5.82},
#  'clouds': {'all': 1},
#  'dt': 1582508508,
#  'sys': {'type': 1,
#   'id': 4210,
#   'country': 'US',
#   'sunrise': 1582457403,
#   'sunset': 1582496737},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
#Test: Create an endpoint URL for a city. we ise ".status_code" to validate if the address is correct - city found
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
#Test: Create an endpoint URL for a city. If the city is fount in JSON
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
#Test  We retreive data for Boston, and use JSON format to see the data
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 35.42,
#   'feels_like': 27.23,
#   'temp_min': 28.99,
#   'temp_max': 41,
#   'pressure': 1019,
#   'humidity': 55},
#  'visibility': 16093,
#  'wind': {'speed': 5.82},
#  'clouds': {'all': 1},
#  'dt': 1582508508,
#  'sys': {'type': 1,
#   'id': 4210,
#   'country': 'US',
#   'sunrise': 1582457403,
#   'sunset': 1582496737},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
#obtained Boston data is a dictionary with nested dictionaries, we define variables to the values of nested dictionary
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
description = boston_data["weather"][0]["description"]
rain = boston_data["rain"][1h]
print(lat, lng, max_temp, humidity, clouds, wind,description,rain)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-5bd1ed6c4328> in <module>
#       7 wind = boston_data["wind"]["speed"]
#       8 description = boston_data["weather"][0]["description"]
# ----> 9 rain = boston_data["rain"]
#      10 print(lat, lng, max_temp, humidity, clouds, wind,description,rain)
#
# KeyError: 'rain'

# %%
# Import the datetime module from the datetime library to convert date and time from UTC format to normal date time
from datetime import datetime

# Get the date from the JSON file. It will come in UTC format
date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.

city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# %%
# Loop through all the cities in the list.
#we gave two iterators i (for record number) and city,
#we iterate on cities list
#we use "enumerate" because we cycle over the dictionary   

city_found = 0
city_not_found = 0

#1 we need to use enumerate because have two iteratives "i" and "city"
#if just write for i, city in cities: we will get error "too many values to unpack", so we use the city use "enumerate(list)"

#2we use "enumerate" because we cycle over the dictionary - nooo

#3we use enumerate because we have two iteratives i and city- yesss like in #1

for i, city in enumerate(cities):


    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1 #every 50 the set count is +1
        record_count = 1 #every 50 record count is reset to 1
        
    # set endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # WHAT is the point of "record_count ??"
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        city_found +=1

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        city_not_found +=1
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
print(len(city_data))
print(f'city found {city_found}')
print(f'skipped record {city_not_found}')

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
#632 total cities times 9x data per city = 5688 entries
#41 not found cities times 9x data per city = 441 entries
#632 - 41 = 583 cities remaining (look index of data frame) = 5247 entries
city_data_df = pd.DataFrame(city_data)
city_data_df

# %%
#City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed
new_order =["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# %%
city_data_df = city_data_df[new_order]

# %%
city_data_df

# %%
# Create the output file (CSV) with city list
import os

output_data_file = os.path.join("weather_data","cities_1.csv")

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%x")
today

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")
#alpha parameter is the transparency level 0 is transparent 1 is not transparent

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ today)
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.  
#text coordinates is the position of the text printed above the trend line

#text_coordinates = (-40,20)

def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
   #(slope, intercept,r_value, p_value, std_err)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    plt.title(title)
    
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()
    print(f"The p-value is is: {p_value:.3f}")
    print(f"the standard errir is: {r_value:.3f}")

# %%
plot_linear_regression(lats,max_temps,"City Latitude vs. Max Temperature ", "Max Temperature (F)", (-40,20))

# %%
#looking at all data in row with index 13
index13 = city_data_df.loc[13]
index13

# %%
#filtering condition
city_data_df["Lat"]>=0

# %%
#filtering data frame
#data_frame_name[filtering condition]
city_data_df.loc[(city_data_df["Lat"]>=0)]

#interesting: we could drop .loc and use only filtering condition and it still would work, inner brackets () also not needed

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
northern_hemi_df

# %%
southern_hemi_df

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for \n Maximum Temperature', 'Max Temp',(0,-20))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for \n Maximum Temperature', 'Max Temp',(-30,50))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-21,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for %Cloudiness', '%Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for %Cloudiness', '%Cloudiness',(-21,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(0,30))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-21,15))
