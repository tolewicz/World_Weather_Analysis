# %%
import pandas as pd
import numpy as np
from citipy import citipy

# %%
#getting coordinates by using random numbers between -90,90 and -180,180

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.

x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
#Shows how the data are printed

for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
#we have a list named coordinates where random coordinates are put

coordinates = list(lat_lngs)

#checking how many coordinates we get - 1500
len(coordinates)
# Out:
# 1500

# %%
# Use the citipy module to determine city based on latitude and longitude.
#the module check if there is any city nearby 

from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
#if there is no city nearby the coordinate is dropped

for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# batagay ru
# punta arenas cl
# saint george bm
# taolanaro mg
# atuona pf
# placido de castro br
# new norfolk au
# rikitea pf
# placido de castro br
# upernavik gl
# sorong id
# hilo us
# vaini to
# namibe ao
# luderitz na
# geraldton au
# zhigansk ru
# george za
# jamestown sh
# iqaluit ca
# paita pe
# ushuaia ar
# gambela et
# chokurdakh ru
# ancud cl
# hermanus za
# russell nz
# kapaa us
# saskylakh ru
# yellowknife ca
# vaini to
# miandrivazo mg
# muborak uz
# albany au
# jamestown sh
# samusu ws
# tsihombe mg
# bredasdorp za
# asau tv
# necochea ar
# taolanaro mg
# pevek ru
# puerto del rosario es
# san patricio mx
# amapa br
# vaini to
# tiksi ru
# rikitea pf
# tuktoyaktuk ca
# amderma ru
# hobart au
# east london za
# ribeira grande pt
# thompson ca
# ushuaia ar
# mattru sl
# bairiki ki
# tumannyy ru
# guerrero negro mx
# ilulissat gl
# juifang tw
# bredasdorp za
# harper lr
# albany au
# bathsheba bb
# iralaya hn
# jiuquan cn
# fort nelson ca
# ngukurr au
# qaanaaq gl
# marystown ca
# bredasdorp za
# upernavik gl
# toliary mg
# kavaratti in
# tuktoyaktuk ca
# hithadhoo mv
# harper lr
# qaanaaq gl
# houma us
# somerset us
# cape town za
# anshun cn
# busselton au
# grindavik is
# axim gh
# nanortalik gl
# puerto ayora ec
# bambous virieux mu
# tasiilaq gl
# mailani in
# kieta pg
# kavieng pg
# port alfred za
# ushuaia ar
# pangnirtung ca
# nanortalik gl
# albany au
# kautokeino no
# namibe ao
# avera pf
# sakakah sa
# bluff nz
# nikolskoye ru
# albany au
# punta arenas cl
# bambous virieux mu
# cape town za
# albany au
# lazaro cardenas mx
# cockburn town bs
# goldsboro us
# amderma ru
# atuona pf
# gautier us
# olinda br
# tuktoyaktuk ca
# tumannyy ru
# bluff nz
# hobart au
# kaitangata nz
# barrow us
# shelburne ca
# coquimbo cl
# juybar ir
# codrington ag
# pisco pe
# christchurch nz
# jamestown sh
# touros br
# bredasdorp za
# new norfolk au
# saint anthony ca
# komsomolskiy ru
# nelson bay au
# amapa br
# ilhabela br
# san marcos mx
# tuktoyaktuk ca
# avarua ck
# punta arenas cl
# rikitea pf
# domoni km
# ostrovnoy ru
# busselton au
# cape town za
# hobart au
# busselton au
# cape town za
# deputatskiy ru
# atuona pf
# hervey bay au
# ushuaia ar
# saldanha za
# bluff nz
# yellowknife ca
# cape town za
# byron bay au
# varena lt
# punta arenas cl
# cape town za
# hokitika nz
# isangel vu
# atuona pf
# punta arenas cl
# warqla dz
# batticaloa lk
# hobart au
# stromness gb
# albany au
# murgab tm
# kavieng pg
# ribeira grande pt
# basco ph
# kodiak us
# thompson ca
# digoin fr
# grand river south east mu
# rongcheng cn
# nevsehir tr
# salinopolis br
# ariquemes br
# pafos cy
# punta arenas cl
# aklavik ca
# rikitea pf
# thompson ca
# mackay au
# punta arenas cl
# corsicana us
# punta arenas cl
# rosarito mx
# rikitea pf
# mataura pf
# luderitz na
# qaanaaq gl
# igarka ru
# bambous virieux mu
# hilo us
# ishigaki jp
# arraial do cabo br
# vila franca do campo pt
# yellowknife ca
# zolotinka ru
# jamestown sh
# cape town za
# upernavik gl
# albany au
# atuona pf
# los andes cl
# hobyo so
# la oroya pe
# barrow us
# barentsburg sj
# tumannyy ru
# belushya guba ru
# hilo us
# sumbawa id
# bluff nz
# puerto ayora ec
# taolanaro mg
# taolanaro mg
# ushuaia ar
# bethel us
# meyungs pw
# punta arenas cl
# hermanus za
# east london za
# busselton au
# arraial do cabo br
# puerto ayora ec
# nikolskoye ru
# sao filipe cv
# mahebourg mu
# dunedin nz
# bathsheba bb
# avarua ck
# taolanaro mg
# port keats au
# mataura pf
# illoqqortoormiut gl
# coahuayana mx
# kashi cn
# hilo us
# maridi sd
# rikitea pf
# palmer us
# saldanha za
# mataura pf
# longlac ca
# cherskiy ru
# hobart au
# jinka et
# victoria sc
# rikitea pf
# mataura pf
# camargo bo
# tyup kg
# narsaq gl
# georgetown sh
# chapais ca
# saleaula ws
# nome us
# mar del plata ar
# bethel us
# broome au
# mys shmidta ru
# tamandare br
# ushuaia ar
# albany au
# abu dhabi ae
# neya ru
# champerico gt
# khatanga ru
# chuy uy
# tiznit ma
# nikolskoye ru
# taolanaro mg
# sangmelima cm
# belmonte br
# bredasdorp za
# port hedland au
# srednekolymsk ru
# lebu cl
# port alfred za
# hilo us
# puerto ayora ec
# bodden town ky
# richards bay za
# sorong id
# pangody ru
# butaritari ki
# ushuaia ar
# itzehoe de
# hobart au
# albany au
# san jose gt
# belushya guba ru
# chilca pe
# manavalakurichi in
# punta arenas cl
# jamestown sh
# miri my
# khatanga ru
# kapaa us
# auki sb
# broken hill au
# yushu cn
# tambul sd
# rikitea pf
# evensk ru
# georgetown sh
# nikolskoye ru
# pimentel pe
# pisco pe
# rikitea pf
# cockburn town tc
# east london za
# labuhan id
# rikitea pf
# vaitupu wf
# vila vu
# uyuni bo
# plouzane fr
# mataura pf
# hobart au
# srednekolymsk ru
# batemans bay au
# talnakh ru
# albany au
# hobart au
# esperance au
# codrington ag
# hermanus za
# ambon id
# touros br
# hobart au
# vanderhoof ca
# bambous virieux mu
# butaritari ki
# bluff nz
# puerto ayora ec
# lishui cn
# mahebourg mu
# atuona pf
# rio grande br
# kaitangata nz
# goderich sl
# atuona pf
# alto longa br
# rikitea pf
# dunedin nz
# ushuaia ar
# puerto ayora ec
# forestville ca
# vila franca do campo pt
# illoqqortoormiut gl
# platanos gr
# chokurdakh ru
# norman wells ca
# ca mau vn
# rikitea pf
# merauke id
# guerrero negro mx
# vila velha br
# ponta do sol cv
# makakilo city us
# la macarena co
# kodiak us
# punta arenas cl
# qaanaaq gl
# lavrentiya ru
# taolanaro mg
# pochutla mx
# nikolskoye ru
# vanimo pg
# rikitea pf
# ixtapa mx
# mataura pf
# belushya guba ru
# boralday kz
# najran sa
# dasoguz tm
# ushuaia ar
# marawi sd
# east london za
# pokhara np
# busselton au
# upernavik gl
# punta arenas cl
# atuona pf
# albany au
# yellowknife ca
# isangel vu
# ushuaia ar
# hobart au
# qaanaaq gl
# boa vista br
# pundaguitan ph
# talnakh ru
# chokurdakh ru
# anadyr ru
# kargasok ru
# severo-kurilsk ru
# tuktoyaktuk ca
# mataura pf
# susanville us
# mount isa au
# san patricio mx
# georgetown sh
# ushuaia ar
# narsaq gl
# tergnier fr
# usinsk ru
# avarua ck
# ushuaia ar
# cidreira br
# mataura pf
# severo-kurilsk ru
# goderich sl
# tuktoyaktuk ca
# bluff nz
# chibombo zm
# rikitea pf
# kavieng pg
# airai pw
# barrow us
# college us
# cabra ph
# asyut eg
# pietarsaari fi
# tiksi ru
# namibe ao
# port alfred za
# dikson ru
# hilo us
# verkhoyansk ru
# anadyr ru
# prince albert ca
# taolanaro mg
# qaanaaq gl
# ushuaia ar
# new norfolk au
# severo-kurilsk ru
# manado id
# calvinia za
# qaqortoq gl
# nokaneng bw
# chokurdakh ru
# bredasdorp za
# puerto ayora ec
# kaitangata nz
# tuatapere nz
# andros town bs
# bredasdorp za
# mataura pf
# bluff nz
# punta arenas cl
# jamestown sh
# hilo us
# lincoln nz
# avarua ck
# tuatapere nz
# rikitea pf
# tasiilaq gl
# faanui pf
# atuona pf
# rawatsar in
# saleaula ws
# solovetskiy ru
# richards bay za
# sitka us
# uray ru
# hermanus za
# vaini to
# avarua ck
# bundaberg au
# tilichiki ru
# gaogou cn
# rikitea pf
# hibbing us
# praya id
# mataura pf
# flin flon ca
# vaini to
# punta arenas cl
# mugur-aksy ru
# barrow us
# dikson ru
# puerto ayora ec
# hilo us
# chokurdakh ru
# dalbandin pk
# north branch us
# vaini to
# ushuaia ar
# chagda ru
# perafita pt
# port alfred za
# sabha ly
# chokurdakh ru
# sentyabrskiy ru
# jamestown sh
# lebu cl
# mataura pf
# puerto ayora ec
# kodiak us
# nikolskoye ru
# sentyabrskiy ru
# san jose gt
# taolanaro mg
# souillac mu
# bambous virieux mu
# dikson ru
# mataura pf
# khatanga ru
# yellowknife ca
# kavieng pg
# kruisfontein za
# trier de
# sitka us
# chacabuco ar
# tongchuan cn
# jamestown sh
# waingapu id
# atuona pf
# marcona pe
# kapaa us
# hihifo to
# tari pg
# leningradskiy ru
# upernavik gl
# belaya gora ru
# bredasdorp za
# san quintin mx
# nikolskoye ru
# ushuaia ar
# mahebourg mu
# hay river ca
# dikson ru
# atuona pf
# lebu cl
# sterling us
# kapaa us
# samusu ws
# new norfolk au
# pindwara in
# hobart au
# yaan cn
# aswan eg
# ancud cl
# albany au
# deputatskiy ru
# te anau nz
# pastavy by
# attawapiskat ca
# buala sb
# kavieng pg
# catuday ph
# dingle ie
# namibe ao
# mataura pf
# ushuaia ar
# bukama cd
# jamestown sh
# nzega tz
# tezu in
# barrow us
# lebu cl
# ayer itam my
# taolanaro mg
# taolanaro mg
# nizhneyansk ru
# isangel vu
# rio gallegos ar
# gat ly
# nizhneyansk ru
# albany au
# jamestown sh
# illoqqortoormiut gl
# pevek ru
# kabinda cd
# nuuk gl
# hobart au
# hilo us
# halalo wf
# san vicente ph
# atuona pf
# vostok ru
# okhotsk ru
# tala eg
# vardo no
# severo-kurilsk ru
# mataura pf
# axim gh
# clyde river ca
# mahebourg mu
# saleaula ws
# oranjemund na
# rafai cf
# yellowknife ca
# busselton au
# namibe ao
# mataura pf
# longyearbyen sj
# cape town za
# vaini to
# tambovka ru
# hilo us
# chernyshevskiy ru
# thompson ca
# taolanaro mg
# port hardy ca
# ancud cl
# batagay-alyta ru
# punta arenas cl
# puerto baquerizo moreno ec
# bilma ne
# hobart au
# hobart au
# khonuu ru
# chenghai cn
# ibipeba br
# vaini to
# bambous virieux mu
# isa khel pk
# busselton au
# ushuaia ar
# dubai ae
# kruisfontein za
# la ronge ca
# xuddur so
# puerto ayora ec
# bambous virieux mu
# anchorage us
# jamestown sh
# esperance au
# mys shmidta ru
# hobart au
# vaitupu wf
# shawnee us
# cabo san lucas mx
# hilo us
# gao ml
# taolanaro mg
# taolanaro mg
# hermanus za
# bluff nz
# mataura pf
# rikitea pf
# butaritari ki
# ushuaia ar
# hilo us
# rikitea pf
# oxford us
# albany au
# mataura pf
# najran sa
# san carlos de bariloche ar
# punta arenas cl
# sitka us
# tsihombe mg
# yar-sale ru
# dudinka ru
# bairiki ki
# tabiauea ki
# albany au
# xiaoweizhai cn
# nizhneyansk ru
# male mv
# srednekolymsk ru
# tual id
# bredasdorp za
# santiago de cao pe
# bredasdorp za
# saurimo ao
# busselton au
# yar-sale ru
# belushya guba ru
# victoria sc
# comodoro rivadavia ar
# thompson ca
# zeya ru
# punta arenas cl
# nikolskoye ru
# tasiilaq gl
# nakasongola ug
# balkhash kz
# waitati nz
# hobart au
# port alfred za
# butaritari ki
# illoqqortoormiut gl
# nanzhang cn
# college us
# idrinskoye ru
# rikitea pf
# punta arenas cl
# luderitz na
# sao borja br
# georgetown sh
# torbay ca
# barawe so
# broken hill au
# nago jp
# kapaa us
# morondava mg
# halalo wf
# alihe cn
# samusu ws
# yellowknife ca
# tazovskiy ru
# maloy no
# busselton au
# hays us
# atuona pf
# vaini to
# mar del plata ar
# upernavik gl
# miri my
# acatlan mx
# barrow us
# nizhneyansk ru
# goderich sl
# smithers ca
# barentsburg sj
# busselton au
# vaini to
# hermanus za
# humaita br
# sant feliu de guixols es
# raymond ca
# cockburn town tc
# jamestown sh
# sistranda no
# new norfolk au
# sentyabrskiy ru
# price us
# airai pw
# souillac mu
# cape town za
# kahului us
# chokwe mz
# ushuaia ar
# mataura pf
# butaritari ki
# longyearbyen sj
# puerto ayora ec
# goderich sl
# hilo us
# ushuaia ar
# ribeira grande pt
# beringovskiy ru
# pevek ru
# tuatapere nz
# tiksi ru
# saint-augustin ca
# lorengau pg
# butaritari ki
# tuktoyaktuk ca
# nouadhibou mr
# taoudenni ml
# alta floresta br
# port-gentil ga
# rikitea pf
# sioux lookout ca
# busselton au
# bredasdorp za
# zdvinsk ru
# hihifo to
# roald no
# klaksvik fo
# samarai pg
# quetta pk
# chuy uy
# karaul ru
# avarua ck
# valdivia cl
# rio cuarto ar
# bengkulu id
# dikson ru
# ahipara nz
# saint-philippe re
# karpathos gr
# geseke de
# talas kg
# mareeba au
# san patricio mx
# verkhoyansk ru
# barrow us
# walvis bay na
# rocha uy
# cape town za
# bouna ci
# zimovniki ru
# dikson ru
# jinchengjiang cn
# atuona pf
# ruiru ke
# saskylakh ru
# carnarvon au
# jalu ly
# chokurdakh ru
# arraial do cabo br
# barrow us
# saint-joseph re
# taolanaro mg
# grand river south east mu
# noumea nc
# chifeng cn
# albany au
# severo-kurilsk ru
# gondar et
# male mv
# atuona pf
# rikitea pf
# saint-philippe re
# ushuaia ar
# puerto ayora ec
# nikolskoye ru
# manokwari id
# kadi in
# shitanjing cn
# sakakah sa
# ushuaia ar
# hilo us
# nikolskoye ru
# pisco pe
# ushuaia ar
# mahebourg mu
# birin dz
# mataura pf
# bethel us
# mys shmidta ru
# mataura pf
# roblin ca
# ushuaia ar
# mataura pf
# east london za
# busselton au
# lahaina us
# bandarbeyla so
# port alfred za
# ardakan ir
# avarua ck
# kollumerland nl
# belushya guba ru
# rikitea pf
# hamilton bm
# lebu cl
# takoradi gh
# sokoto ng
# san jeronimo pe
# isoka zm
# tuktoyaktuk ca
# cabo san lucas mx
# kodiak us
# toliary mg
# bredasdorp za
# sitka us
# broken hill au
# port elizabeth za
# nerchinskiy zavod ru
# rikitea pf
# bur gabo so
# bluff nz
# sungairaya id
# saint-philippe re
# lavrentiya ru
# hobart au
# mataura pf
# laguna br
# vidim ru
# vestmannaeyjar is
# muros es
# tsihombe mg
# victoria sc
# albany au
# qaanaaq gl
# husavik is
# ancud cl
# hilo us
# lebu cl
# vaini to
# lincoln us
# canico pt
# kapaa us
# hovd mn
# amderma ru
# kaitangata nz
# hilo us
# yellowknife ca
# moranbah au
# chokurdakh ru
# vaini to
# ancud cl
# khatanga ru
# busselton au
# ushuaia ar
# mount gambier au
# bambous virieux mu
# pangnirtung ca
# attawapiskat ca
# longyearbyen sj
# provideniya ru
# mataura pf
# new norfolk au
# hun ly
# butaritari ki
# thompson ca
# mys shmidta ru
# butaritari ki
# svetlyy ru
# chipinge zw
# barrow us
# kidal ml
# victoria sc
# albany au
# chumikan ru
# hilo us
# belushya guba ru
# tuktoyaktuk ca
# barawe so
# bluff nz
# flin flon ca
# port elizabeth za
# victoria sc
# bluff nz
# guerrero negro mx
# ahipara nz
# qaanaaq gl
# ishikari jp
# mys shmidta ru
# codrington ag
# khatanga ru
# ushuaia ar
# mount gambier au
# lasem id
# kharan pk
# hermanus za
# clyde river ca
# ugoofaaru mv
# ponta do sol cv
# toamasina mg
# busselton au
# roebourne au
# turukhansk ru
# hami cn
# la ermita mx
# upernavik gl
# kodiak us
# mangrol in
# atuona pf
# albany au
# samusu ws
# barentsburg sj
# bluff nz
# abu dhabi ae
# port alfred za
# busselton au
# jamestown sh
# vaini to
# rabo de peixe pt
# kathu th
# saint george bm
# hambantota lk
# daru pg
# saint-philippe re
# inta ru
# puerto ayora ec
# jamestown sh
# nikolskoye ru
# carnarvon au
# narsaq gl
# ushuaia ar
# rikitea pf
# tuktoyaktuk ca
# yellowknife ca
# hualmay pe
# khatanga ru
# rio gallegos ar
# atuona pf
# yellowknife ca
# ushuaia ar
# saskylakh ru
# lebu cl
# sorvag fo
# novopokrovka ru
# havelock us
# ushuaia ar
# burica pa
# barrow us
# jamestown sh
# mataura pf
# la vista us
# kristinehamn se
# osmena ph
# yellowknife ca
# auki sb
# luderitz na
# cape town za
# flagstaff us
# upernavik gl
# maragheh ir
# punta arenas cl
# totness sr
# port alfred za
# jamestown sh
# vestmannaeyjar is
# homer us
# stonewall ca
# navolato mx
# cape town za
# georgetown sh
# busselton au
# lagoa pt
# fortuna us
# luderitz na
# bethel us
# lata sb
# salalah om
# punta arenas cl
# port alfred za
# mataura pf
# avarua ck
# arraial do cabo br
# college us
# jamestown sh
# boguchany ru
# kitimat ca
# cape town za
# clyde river ca
# lasa cn
# cherskiy ru
# isangel vu
# arraial do cabo br
# rikitea pf
# adrar dz
# pevek ru
# daru pg
# ushuaia ar
# menongue ao
# ushuaia ar
# waddan ly
# poum nc
# georgetown sh
# dikson ru
# leningradskiy ru
# kruisfontein za
# skalistyy ru
# bang saphan th
# nikolskoye ru
# cape town za
# grand river south east mu
# haines junction ca
# upernavik gl
# blackwater au
# kungurtug ru
# nikolskoye ru
# sapao ph
# punta arenas cl
# nouadhibou mr
# salalah om
# butaritari ki
# kiunga pg
# esperance au
# rapid valley us
# necochea ar
# hithadhoo mv
# lasa cn
# kuche cn
# nylstroom za
# cape town za
# rikitea pf
# bathsheba bb
# gisenyi rw
# kapaa us
# gayny ru
# aripuana br
# muravlenko ru
# ushuaia ar
# apatity ru
# iqaluit ca
# pevek ru
# albany au
# chiang klang th
# bredasdorp za
# khatanga ru
# taolanaro mg
# nikolskoye ru
# comodoro rivadavia ar
# zyryanka ru
# hithadhoo mv
# liwale tz
# pangnirtung ca
# hofn is
# sabak my
# port alfred za
# punta arenas cl
# touros br
# kodiak us
# provideniya ru
# bambari cf
# atuona pf
# bucerias mx
# palabuhanratu id
# haslett us
# muika jp
# sao filipe cv
# ribeira grande pt
# albany au
# saldanha za
# ushuaia ar
# solnechnyy ru
# qaanaaq gl
# tasiilaq gl
# beloha mg
# mataura pf
# srandakan id
# hamilton bm
# albany au
# sentyabrskiy ru
# atuona pf
# tazovskiy ru
# grindavik is
# dikson ru
# barentsburg sj
# mataura pf
# asau tv
# barentsburg sj
# shu kz
# hilo us
# hilo us
# chuy uy
# husavik is
# santa rosa bo
# tasiilaq gl
# port alfred za
# rincon an
# ponta do sol cv
# jamestown sh
# santa cruz cr
# broken hill au
# hilo us
# hasaki jp
# nizwa om
# tiksi ru
# rikitea pf
# los llanos de aridane es
# panguna pg
# jamestown sh
# noumea nc
# port elizabeth za
# keetmanshoop na
# puerto ayora ec
# albany au
# kapaa us
# ushuaia ar
# whitehorse ca
# jaisalmer in
# pevek ru
# saldanha za
# airai pw
# mys shmidta ru
# phangnga th
# tawang in
# tura ru
# jiangkou cn
# sitangkai ph
# norman wells ca
# kralendijk an
# taolanaro mg
# butaritari ki
# nikolskoye ru
# hermanus za
# ontario us
# batagay ru
# port alfred za
# santa maria cv
# sechura pe
# leningradskiy ru
# lebu cl
# kahului us
# taolanaro mg
# manggar id
# maragogi br
# umzimvubu za
# kibre mengist et
# ushuaia ar
# muisne ec
# rikitea pf
# kloulklubed pw
# rikitea pf
# carman ca
# san vicente ph
# rikitea pf
# jamestown sh
# thompson ca
# albany au
# mys shmidta ru
# busselton au
# sirjan ir
# tuktoyaktuk ca
# laja cl
# grand river south east mu
# grenada us
# bolshaya murta ru
# sungaipenuh id
# alyangula au
# high prairie ca
# vaini to
# yellowknife ca
# namatanai pg
# barentsburg sj
# lakatoro vu
# torbay ca
# illoqqortoormiut gl
# bayshore gardens us
# viedma ar
# hobart au
# dingle ie
# ancud cl
# arman ru
# cape town za
# narsaq gl
# pucallpa pe
# haapiti pf
# yulara au
# rikitea pf
# hithadhoo mv
# dubbo au
# yellowknife ca
# atuona pf
# hilo us
# bubaque gw
# butaritari ki
# malwan in
# ca mau vn
# akyab mm
# ponta do sol pt
# srednekolymsk ru
# ushuaia ar
# clyde river ca
# nyuksenitsa ru
# ushuaia ar
# bluff nz
# saint-joseph re
# dikson ru
# atuona pf
# victoria sc
# sentyabrskiy ru
# paamiut gl
# yellowknife ca
# bluff nz
# hobart au
# jamestown sh
# pevek ru
# kodiak us
# manjo cm
# barrow us
# tsihombe mg
# attawapiskat ca
# hithadhoo mv
# luderitz na
# cayenne gf
# hermanus za
# itarema br
# marawi sd
# bredasdorp za
# manama bh
# albion mu
# kruisfontein za
# eureka us
# komsomolskiy ru
# bayan kw
# amderma ru
# georgetown sh
# hobart au
# tuktoyaktuk ca
# caravelas br
# amderma ru
# kavaratti in
# praia da vitoria pt
# nome us
# dikson ru
# kholodnyy ru
# arraial do cabo br
# port alfred za
# tazovskiy ru
# ancud cl
# mataura pf
# verkhnyaya inta ru
# kapaa us
# bredasdorp za
# ngukurr au
# tuktoyaktuk ca
# maragogi br
# nikolskoye ru
# tuktoyaktuk ca
# ribeira grande pt
# kapaa us
# nicoya cr
# barrow us
# hilo us
# kruisfontein za
# rikitea pf
# georgetown sh
# port elizabeth za
# tocantinopolis br
# nome us
# qaanaaq gl
# avarua ck
# taolanaro mg
# khatanga ru
# carnarvon au
# chengde cn
# new norfolk au
# belushya guba ru
# chinsali zm
# nikolskoye ru
# rikitea pf
# suez eg
# vaini to
# norman wells ca
# kisangani cd
# kudahuvadhoo mv
# albany au
# saint-philippe re
# busselton au
# jamestown sh
# ribeira grande pt
# bredasdorp za
# atar mr
# makakilo city us
# hay river ca
# isangel vu
# rikitea pf
# severo-kurilsk ru
# kavaratti in
# tiksi ru
# barrow us
# fairborn us
# mataura pf
# taksimo ru
# lorengau pg
# albany au
# mahaicony gy
# khammam in
# marcona pe
# jamestown sh
# illoqqortoormiut gl
# borzoy ru
# ushuaia ar
# dunedin nz
# morant bay jm
# vestmannaeyjar is
# castro cl
# qaanaaq gl
# portland au
# prestea gh
# monrovia lr
# rikitea pf
# atuona pf
# umzimvubu za
# alice springs au
# bredasdorp za
# mataura pf
# balakhta ru
# kaitangata nz
# marion us
# newport us
# kavaratti in
# lebu cl
# busselton au
# nikolskoye ru
# ushuaia ar
# bluff nz
# saint-joseph re
# inhambane mz
# bredasdorp za
# guiratinga br
# narsaq gl
# prince rupert ca
# marystown ca
# ushuaia ar
# dovolnoye ru
# rikitea pf
# mataura pf
# cabo san lucas mx
# rikitea pf
# albany au
# mayo ca
# hithadhoo mv
# hami cn
# geraldton au
# castro alves br
# bluff nz
# ostrovnoy ru
# kodiak us
# coruripe br
# kaitangata nz
# mahebourg mu
# saint-philippe re
# turukhansk ru
# khatanga ru
# kamyaran ir
# tiksi ru
# port alfred za
# longyearbyen sj
# te anau nz
# qaanaaq gl
# rikitea pf
# rikitea pf
# punta alta ar
# griffith au
# mataura pf
# los llanos de aridane es
# aguas formosas br
# ushuaia ar
# georgetown sh
# ahipara nz
# scottsbluff us
# vaini to
# albany au
# neya ru
# hermanus za
# rikitea pf
# clyde river ca
# taolanaro mg
# castro cl
# taolanaro mg
# illoqqortoormiut gl
# kapaa us
# goundam ml
# east london za
# arman ru
# rikitea pf
# hutchinson us
# rikitea pf
# jiexiu cn
# campo verde br
# okhotsk ru
# rikitea pf
# lavrentiya ru
# avarua ck
# ushuaia ar
# albany au
# glasgow us
# ponta do sol cv
# itupeva br
# mar del plata ar
# ushuaia ar
# eslamshahr ir
# punta arenas cl
# ushuaia ar
# pathein mm
# longyearbyen sj
# port elizabeth za
# torbay ca
# victoria sc
# hilo us
# rikitea pf
# kargat ru
# busselton au
# waipawa nz
# taolanaro mg
# srednekolymsk ru
# ushuaia ar
# san quintin mx
# ulladulla au
# montero bo
# tacuarembo uy
# ponta do sol cv
# kapaa us
# ushuaia ar
# mys shmidta ru
# umm lajj sa
# butaritari ki
# revelstoke ca
# kavaratti in
# sentyabrskiy ru
# broome au
# mataura pf
# rikitea pf
# lompoc us
# vostok ru
# barrow us
# punta arenas cl
# meyungs pw
# east london za
# ushuaia ar
# rikitea pf
# malindi ke
# port alfred za
# chokurdakh ru
# clyde river ca
# tura ru
# belushya guba ru
# butaritari ki
# port elizabeth za

# %%
# Create a list for holding the cities. so if there is no city it will not show in the list 
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
#so the number of entries was decreased from 1500 to ~500
len(cities)
# Out:
# 612

# %%
import requests
requests.__version__
# Out:
# '2.22.0'

# %%
# Import the requests library.
import requests

# Import the API key.
#I got a separate python program named config. this command request accessing the program and getting 
#"weather_api_key" variable which has my key

from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0fed1d27c890bee23d79b7e2c72378ec

# %%
# Test: Create an endpoint URL for a city - the address from which we will retreive data
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0fed1d27c890bee23d79b7e2c72378ec&q=Boston

# %%
# Test: Make a 'Get' request for the city weather. Response 200, means address exist
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Test: Create an endpoint URL for a city that doesn't exist. 404 means the address doesn't exist or no access
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Test: Create an endpoint URL for a city using JSON. JSON will always return the status code 200 if exist
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
#Test: Get the text of the 'Get' request. We getting a dictionary with keys: "cord","weather" etc. and nested dictionary as value
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"base":"stations","main":{"temp":25.2,"feels_like":9.97,"temp_min":21,"temp_max":28.99,"pressure":1021,"humidity":38},"wind":{"speed":16.11,"deg":230,"gust":23.04},"clouds":{"all":0},"dt":1582359889,"sys":{"type":1,"id":4967,"country":"US","sunrise":1582371094,"sunset":1582410262},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 25.2,
#   'feels_like': 9.97,
#   'temp_min': 21,
#   'temp_max': 28.99,
#   'pressure': 1021,
#   'humidity': 38},
#  'wind': {'speed': 16.11, 'deg': 230, 'gust': 23.04},
#  'clouds': {'all': 0},
#  'dt': 1582359889,
#  'sys': {'type': 1,
#   'id': 4967,
#   'country': 'US',
#   'sunrise': 1582371094,
#   'sunset': 1582410262},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
#Test: Create an endpoint URL for a city. we ise ".status_code" to validate if the address is correct - city found
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
#Test: Create an endpoint URL for a city. If the city is fount in JSON
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
#Test  We retreive data for Boston, and use JSON format to see the data
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 25.2,
#   'feels_like': 9.97,
#   'temp_min': 21,
#   'temp_max': 28.99,
#   'pressure': 1021,
#   'humidity': 38},
#  'wind': {'speed': 16.11, 'deg': 230, 'gust': 23.04},
#  'clouds': {'all': 0},
#  'dt': 1582359889,
#  'sys': {'type': 1,
#   'id': 4967,
#   'country': 'US',
#   'sunrise': 1582371094,
#   'sunset': 1582410262},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
#obtained Boston data is a dictionary with nested dictionaries, we define variables to the values of nested dictionary
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 28.99 38 0 16.11

# %%
# Import the datetime module from the datetime library to convert date and time from UTC format to normal date time
from datetime import datetime

# Get the date from the JSON file. It will come in UTC format
date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2020, 2, 22, 8, 24, 49)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.

city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
#we gave two iterators i (for record number) and city,
#we iterate on cities list
#we use "enumerate" because we cycle over the dictionary   

city_found = 0
city_not_found = 0

#1 we need to use enumerate because have two iteratives "i" and "city"
#if just write for i, city in cities: we will get error "too many values to unpack", so we use the city use "enumerate(list)"

#2we use "enumerate" because we cycle over the dictionary - nooo

#3we use enumerate because we have two iteratives i and city- yesss like in #1

for i, city in enumerate(cities):


    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1 #every 50 the set count is +1
        record_count = 1 #every 50 record count is reset to 1
        
    # set endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # WHAT is the point of "record_count ??"
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        city_found +=1

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        city_not_found +=1
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
print(len(city_data))
print(f'city found {city_found}')
print(f'skipped record {city_not_found}')
# Out:
# Processing Record 1 of Set 1 | batagay
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | saint george
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | placido de castro
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | sorong
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | namibe
# Processing Record 14 of Set 1 | luderitz
# Processing Record 15 of Set 1 | geraldton
# Processing Record 16 of Set 1 | zhigansk
# Processing Record 17 of Set 1 | george
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | paita
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | gambela
# Processing Record 23 of Set 1 | chokurdakh
# Processing Record 24 of Set 1 | ancud
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | russell
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | saskylakh
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | miandrivazo
# Processing Record 31 of Set 1 | muborak
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | asau
# Processing Record 37 of Set 1 | necochea
# Processing Record 38 of Set 1 | pevek
# Processing Record 39 of Set 1 | puerto del rosario
# Processing Record 40 of Set 1 | san patricio
# Processing Record 41 of Set 1 | amapa
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | mattru
# Processing Record 50 of Set 1 | bairiki
# Processing Record 1 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 2 | guerrero negro
# Processing Record 3 of Set 2 | ilulissat
# Processing Record 4 of Set 2 | juifang
# City not found. Skipping...
# Processing Record 5 of Set 2 | harper
# Processing Record 6 of Set 2 | bathsheba
# Processing Record 7 of Set 2 | iralaya
# Processing Record 8 of Set 2 | jiuquan
# Processing Record 9 of Set 2 | fort nelson
# Processing Record 10 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | marystown
# Processing Record 13 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 2 | kavaratti
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | houma
# Processing Record 17 of Set 2 | somerset
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | anshun
# Processing Record 20 of Set 2 | busselton
# Processing Record 21 of Set 2 | grindavik
# Processing Record 22 of Set 2 | axim
# Processing Record 23 of Set 2 | nanortalik
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | bambous virieux
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | mailani
# Processing Record 28 of Set 2 | kieta
# Processing Record 29 of Set 2 | kavieng
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | pangnirtung
# Processing Record 32 of Set 2 | kautokeino
# Processing Record 33 of Set 2 | avera
# Processing Record 34 of Set 2 | sakakah
# Processing Record 35 of Set 2 | bluff
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | lazaro cardenas
# Processing Record 38 of Set 2 | cockburn town
# Processing Record 39 of Set 2 | goldsboro
# Processing Record 40 of Set 2 | gautier
# Processing Record 41 of Set 2 | olinda
# Processing Record 42 of Set 2 | kaitangata
# Processing Record 43 of Set 2 | barrow
# Processing Record 44 of Set 2 | shelburne
# Processing Record 45 of Set 2 | coquimbo
# Processing Record 46 of Set 2 | juybar
# Processing Record 47 of Set 2 | codrington
# Processing Record 48 of Set 2 | pisco
# Processing Record 49 of Set 2 | christchurch
# Processing Record 50 of Set 2 | touros
# Processing Record 1 of Set 3 | saint anthony
# Processing Record 2 of Set 3 | komsomolskiy
# Processing Record 3 of Set 3 | nelson bay
# Processing Record 4 of Set 3 | ilhabela
# Processing Record 5 of Set 3 | san marcos
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | domoni
# Processing Record 8 of Set 3 | ostrovnoy
# Processing Record 9 of Set 3 | deputatskiy
# Processing Record 10 of Set 3 | hervey bay
# Processing Record 11 of Set 3 | saldanha
# Processing Record 12 of Set 3 | byron bay
# Processing Record 13 of Set 3 | varena
# Processing Record 14 of Set 3 | hokitika
# Processing Record 15 of Set 3 | isangel
# Processing Record 16 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 3 | batticaloa
# Processing Record 18 of Set 3 | stromness
# Processing Record 19 of Set 3 | murgab
# Processing Record 20 of Set 3 | basco
# Processing Record 21 of Set 3 | kodiak
# Processing Record 22 of Set 3 | digoin
# Processing Record 23 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 3 | rongcheng
# Processing Record 25 of Set 3 | nevsehir
# Processing Record 26 of Set 3 | salinopolis
# Processing Record 27 of Set 3 | ariquemes
# Processing Record 28 of Set 3 | pafos
# Processing Record 29 of Set 3 | aklavik
# Processing Record 30 of Set 3 | mackay
# Processing Record 31 of Set 3 | corsicana
# Processing Record 32 of Set 3 | rosarito
# Processing Record 33 of Set 3 | mataura
# Processing Record 34 of Set 3 | igarka
# Processing Record 35 of Set 3 | ishigaki
# Processing Record 36 of Set 3 | arraial do cabo
# Processing Record 37 of Set 3 | vila franca do campo
# Processing Record 38 of Set 3 | zolotinka
# City not found. Skipping...
# Processing Record 39 of Set 3 | los andes
# Processing Record 40 of Set 3 | hobyo
# Processing Record 41 of Set 3 | la oroya
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 3 | sao filipe
# Processing Record 48 of Set 3 | mahebourg
# Processing Record 49 of Set 3 | dunedin
# Processing Record 50 of Set 3 | port keats
# Processing Record 1 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 4 | coahuayana
# Processing Record 3 of Set 4 | kashi
# Processing Record 4 of Set 4 | maridi
# Processing Record 5 of Set 4 | palmer
# Processing Record 6 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 7 of Set 4 | cherskiy
# Processing Record 8 of Set 4 | jinka
# Processing Record 9 of Set 4 | victoria
# Processing Record 10 of Set 4 | camargo
# Processing Record 11 of Set 4 | tyup
# Processing Record 12 of Set 4 | narsaq
# Processing Record 13 of Set 4 | georgetown
# Processing Record 14 of Set 4 | chapais
# Processing Record 15 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 4 | nome
# Processing Record 17 of Set 4 | mar del plata
# Processing Record 18 of Set 4 | broome
# Processing Record 19 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 4 | tamandare
# Processing Record 21 of Set 4 | abu dhabi
# Processing Record 22 of Set 4 | neya
# Processing Record 23 of Set 4 | champerico
# Processing Record 24 of Set 4 | khatanga
# Processing Record 25 of Set 4 | chuy
# Processing Record 26 of Set 4 | tiznit
# Processing Record 27 of Set 4 | sangmelima
# Processing Record 28 of Set 4 | belmonte
# Processing Record 29 of Set 4 | port hedland
# Processing Record 30 of Set 4 | srednekolymsk
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | bodden town
# Processing Record 33 of Set 4 | richards bay
# Processing Record 34 of Set 4 | pangody
# Processing Record 35 of Set 4 | butaritari
# Processing Record 36 of Set 4 | itzehoe
# Processing Record 37 of Set 4 | san jose
# Processing Record 38 of Set 4 | chilca
# Processing Record 39 of Set 4 | manavalakurichi
# Processing Record 40 of Set 4 | miri
# Processing Record 41 of Set 4 | auki
# Processing Record 42 of Set 4 | broken hill
# Processing Record 43 of Set 4 | yushu
# Processing Record 44 of Set 4 | tambul
# City not found. Skipping...
# Processing Record 45 of Set 4 | evensk
# Processing Record 46 of Set 4 | pimentel
# Processing Record 47 of Set 4 | labuhan
# Processing Record 48 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 4 | vila
# Processing Record 50 of Set 4 | uyuni
# Processing Record 1 of Set 5 | plouzane
# Processing Record 2 of Set 5 | batemans bay
# Processing Record 3 of Set 5 | talnakh
# Processing Record 4 of Set 5 | esperance
# Processing Record 5 of Set 5 | ambon
# Processing Record 6 of Set 5 | vanderhoof
# Processing Record 7 of Set 5 | lishui
# Processing Record 8 of Set 5 | rio grande
# Processing Record 9 of Set 5 | goderich
# Processing Record 10 of Set 5 | alto longa
# Processing Record 11 of Set 5 | forestville
# Processing Record 12 of Set 5 | platanos
# Processing Record 13 of Set 5 | norman wells
# Processing Record 14 of Set 5 | ca mau
# Processing Record 15 of Set 5 | merauke
# Processing Record 16 of Set 5 | vila velha
# Processing Record 17 of Set 5 | ponta do sol
# Processing Record 18 of Set 5 | makakilo city
# Processing Record 19 of Set 5 | la macarena
# Processing Record 20 of Set 5 | lavrentiya
# Processing Record 21 of Set 5 | pochutla
# Processing Record 22 of Set 5 | vanimo
# Processing Record 23 of Set 5 | ixtapa
# Processing Record 24 of Set 5 | boralday
# Processing Record 25 of Set 5 | najran
# Processing Record 26 of Set 5 | dasoguz
# Processing Record 27 of Set 5 | marawi
# Processing Record 28 of Set 5 | pokhara
# Processing Record 29 of Set 5 | boa vista
# Processing Record 30 of Set 5 | pundaguitan
# Processing Record 31 of Set 5 | anadyr
# Processing Record 32 of Set 5 | kargasok
# Processing Record 33 of Set 5 | severo-kurilsk
# Processing Record 34 of Set 5 | susanville
# Processing Record 35 of Set 5 | mount isa
# Processing Record 36 of Set 5 | tergnier
# Processing Record 37 of Set 5 | usinsk
# Processing Record 38 of Set 5 | cidreira
# Processing Record 39 of Set 5 | chibombo
# Processing Record 40 of Set 5 | airai
# Processing Record 41 of Set 5 | college
# Processing Record 42 of Set 5 | cabra
# Processing Record 43 of Set 5 | asyut
# Processing Record 44 of Set 5 | pietarsaari
# Processing Record 45 of Set 5 | dikson
# Processing Record 46 of Set 5 | verkhoyansk
# Processing Record 47 of Set 5 | prince albert
# Processing Record 48 of Set 5 | manado
# Processing Record 49 of Set 5 | calvinia
# Processing Record 50 of Set 5 | qaqortoq
# Processing Record 1 of Set 6 | nokaneng
# Processing Record 2 of Set 6 | tuatapere
# Processing Record 3 of Set 6 | andros town
# Processing Record 4 of Set 6 | lincoln
# Processing Record 5 of Set 6 | faanui
# Processing Record 6 of Set 6 | rawatsar
# Processing Record 7 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 8 of Set 6 | sitka
# Processing Record 9 of Set 6 | uray
# Processing Record 10 of Set 6 | bundaberg
# Processing Record 11 of Set 6 | tilichiki
# Processing Record 12 of Set 6 | gaogou
# Processing Record 13 of Set 6 | hibbing
# Processing Record 14 of Set 6 | praya
# Processing Record 15 of Set 6 | flin flon
# Processing Record 16 of Set 6 | mugur-aksy
# Processing Record 17 of Set 6 | dalbandin
# Processing Record 18 of Set 6 | north branch
# Processing Record 19 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 6 | perafita
# Processing Record 21 of Set 6 | sabha
# Processing Record 22 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 6 | souillac
# Processing Record 24 of Set 6 | kruisfontein
# Processing Record 25 of Set 6 | trier
# Processing Record 26 of Set 6 | chacabuco
# Processing Record 27 of Set 6 | tongchuan
# Processing Record 28 of Set 6 | waingapu
# Processing Record 29 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 6 | tari
# Processing Record 32 of Set 6 | leningradskiy
# Processing Record 33 of Set 6 | belaya gora
# Processing Record 34 of Set 6 | san quintin
# Processing Record 35 of Set 6 | hay river
# Processing Record 36 of Set 6 | sterling
# Processing Record 37 of Set 6 | pindwara
# Processing Record 38 of Set 6 | yaan
# Processing Record 39 of Set 6 | aswan
# Processing Record 40 of Set 6 | te anau
# Processing Record 41 of Set 6 | pastavy
# Processing Record 42 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 6 | buala
# Processing Record 44 of Set 6 | catuday
# Processing Record 45 of Set 6 | dingle
# Processing Record 46 of Set 6 | bukama
# Processing Record 47 of Set 6 | nzega
# Processing Record 48 of Set 6 | tezu
# Processing Record 49 of Set 6 | ayer itam
# City not found. Skipping...
# Processing Record 50 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 7 | rio gallegos
# Processing Record 2 of Set 7 | gat
# Processing Record 3 of Set 7 | kabinda
# Processing Record 4 of Set 7 | nuuk
# Processing Record 5 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 7 | san vicente
# Processing Record 7 of Set 7 | vostok
# Processing Record 8 of Set 7 | okhotsk
# Processing Record 9 of Set 7 | tala
# Processing Record 10 of Set 7 | vardo
# Processing Record 11 of Set 7 | clyde river
# Processing Record 12 of Set 7 | oranjemund
# Processing Record 13 of Set 7 | rafai
# Processing Record 14 of Set 7 | longyearbyen
# Processing Record 15 of Set 7 | tambovka
# Processing Record 16 of Set 7 | chernyshevskiy
# Processing Record 17 of Set 7 | port hardy
# Processing Record 18 of Set 7 | batagay-alyta
# Processing Record 19 of Set 7 | puerto baquerizo moreno
# Processing Record 20 of Set 7 | bilma
# Processing Record 21 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 7 | chenghai
# Processing Record 23 of Set 7 | ibipeba
# Processing Record 24 of Set 7 | isa khel
# Processing Record 25 of Set 7 | dubai
# Processing Record 26 of Set 7 | la ronge
# Processing Record 27 of Set 7 | xuddur
# Processing Record 28 of Set 7 | anchorage
# Processing Record 29 of Set 7 | shawnee
# Processing Record 30 of Set 7 | cabo san lucas
# Processing Record 31 of Set 7 | gao
# Processing Record 32 of Set 7 | oxford
# Processing Record 33 of Set 7 | san carlos de bariloche
# Processing Record 34 of Set 7 | yar-sale
# Processing Record 35 of Set 7 | dudinka
# Processing Record 36 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 7 | xiaoweizhai
# Processing Record 38 of Set 7 | male
# Processing Record 39 of Set 7 | tual
# Processing Record 40 of Set 7 | santiago de cao
# Processing Record 41 of Set 7 | saurimo
# Processing Record 42 of Set 7 | comodoro rivadavia
# Processing Record 43 of Set 7 | zeya
# Processing Record 44 of Set 7 | nakasongola
# Processing Record 45 of Set 7 | balkhash
# Processing Record 46 of Set 7 | waitati
# Processing Record 47 of Set 7 | nanzhang
# Processing Record 48 of Set 7 | idrinskoye
# Processing Record 49 of Set 7 | sao borja
# Processing Record 50 of Set 7 | torbay
# Processing Record 1 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 2 of Set 8 | nago
# Processing Record 3 of Set 8 | morondava
# Processing Record 4 of Set 8 | alihe
# Processing Record 5 of Set 8 | tazovskiy
# Processing Record 6 of Set 8 | maloy
# Processing Record 7 of Set 8 | hays
# Processing Record 8 of Set 8 | acatlan
# Processing Record 9 of Set 8 | smithers
# Processing Record 10 of Set 8 | humaita
# Processing Record 11 of Set 8 | sant feliu de guixols
# Processing Record 12 of Set 8 | raymond
# Processing Record 13 of Set 8 | sistranda
# Processing Record 14 of Set 8 | price
# Processing Record 15 of Set 8 | kahului
# Processing Record 16 of Set 8 | chokwe
# Processing Record 17 of Set 8 | beringovskiy
# Processing Record 18 of Set 8 | saint-augustin
# Processing Record 19 of Set 8 | lorengau
# Processing Record 20 of Set 8 | nouadhibou
# Processing Record 21 of Set 8 | taoudenni
# Processing Record 22 of Set 8 | alta floresta
# Processing Record 23 of Set 8 | port-gentil
# Processing Record 24 of Set 8 | sioux lookout
# Processing Record 25 of Set 8 | zdvinsk
# Processing Record 26 of Set 8 | roald
# Processing Record 27 of Set 8 | klaksvik
# Processing Record 28 of Set 8 | samarai
# Processing Record 29 of Set 8 | quetta
# Processing Record 30 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 8 | valdivia
# Processing Record 32 of Set 8 | rio cuarto
# Processing Record 33 of Set 8 | bengkulu
# Processing Record 34 of Set 8 | ahipara
# Processing Record 35 of Set 8 | saint-philippe
# Processing Record 36 of Set 8 | karpathos
# Processing Record 37 of Set 8 | geseke
# Processing Record 38 of Set 8 | talas
# Processing Record 39 of Set 8 | mareeba
# Processing Record 40 of Set 8 | walvis bay
# Processing Record 41 of Set 8 | rocha
# Processing Record 42 of Set 8 | bouna
# Processing Record 43 of Set 8 | zimovniki
# Processing Record 44 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 45 of Set 8 | ruiru
# Processing Record 46 of Set 8 | carnarvon
# Processing Record 47 of Set 8 | jalu
# Processing Record 48 of Set 8 | saint-joseph
# Processing Record 49 of Set 8 | noumea
# Processing Record 50 of Set 8 | chifeng
# Processing Record 1 of Set 9 | gondar
# Processing Record 2 of Set 9 | manokwari
# Processing Record 3 of Set 9 | kadi
# Processing Record 4 of Set 9 | shitanjing
# Processing Record 5 of Set 9 | birin
# Processing Record 6 of Set 9 | roblin
# Processing Record 7 of Set 9 | lahaina
# Processing Record 8 of Set 9 | bandarbeyla
# Processing Record 9 of Set 9 | ardakan
# Processing Record 10 of Set 9 | kollumerland
# City not found. Skipping...
# Processing Record 11 of Set 9 | hamilton
# Processing Record 12 of Set 9 | takoradi
# Processing Record 13 of Set 9 | sokoto
# Processing Record 14 of Set 9 | san jeronimo
# Processing Record 15 of Set 9 | isoka
# Processing Record 16 of Set 9 | port elizabeth
# Processing Record 17 of Set 9 | nerchinskiy zavod
# Processing Record 18 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 9 | sungairaya
# Processing Record 20 of Set 9 | laguna
# Processing Record 21 of Set 9 | vidim
# Processing Record 22 of Set 9 | vestmannaeyjar
# Processing Record 23 of Set 9 | muros
# Processing Record 24 of Set 9 | husavik
# Processing Record 25 of Set 9 | canico
# Processing Record 26 of Set 9 | hovd
# Processing Record 27 of Set 9 | moranbah
# Processing Record 28 of Set 9 | mount gambier
# Processing Record 29 of Set 9 | provideniya
# Processing Record 30 of Set 9 | hun
# Processing Record 31 of Set 9 | svetlyy
# Processing Record 32 of Set 9 | chipinge
# Processing Record 33 of Set 9 | kidal
# Processing Record 34 of Set 9 | chumikan
# Processing Record 35 of Set 9 | ishikari
# Processing Record 36 of Set 9 | lasem
# Processing Record 37 of Set 9 | kharan
# Processing Record 38 of Set 9 | ugoofaaru
# Processing Record 39 of Set 9 | toamasina
# Processing Record 40 of Set 9 | roebourne
# Processing Record 41 of Set 9 | turukhansk
# Processing Record 42 of Set 9 | hami
# Processing Record 43 of Set 9 | la ermita
# Processing Record 44 of Set 9 | mangrol
# Processing Record 45 of Set 9 | rabo de peixe
# Processing Record 46 of Set 9 | kathu
# Processing Record 47 of Set 9 | hambantota
# Processing Record 48 of Set 9 | daru
# Processing Record 49 of Set 9 | inta
# Processing Record 50 of Set 9 | hualmay
# Processing Record 1 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 10 | novopokrovka
# Processing Record 3 of Set 10 | havelock
# Processing Record 4 of Set 10 | burica
# City not found. Skipping...
# Processing Record 5 of Set 10 | la vista
# Processing Record 6 of Set 10 | kristinehamn
# Processing Record 7 of Set 10 | osmena
# Processing Record 8 of Set 10 | flagstaff
# Processing Record 9 of Set 10 | maragheh
# Processing Record 10 of Set 10 | totness
# Processing Record 11 of Set 10 | homer
# Processing Record 12 of Set 10 | stonewall
# Processing Record 13 of Set 10 | navolato
# Processing Record 14 of Set 10 | lagoa
# Processing Record 15 of Set 10 | fortuna
# Processing Record 16 of Set 10 | lata
# Processing Record 17 of Set 10 | salalah
# Processing Record 18 of Set 10 | boguchany
# Processing Record 19 of Set 10 | kitimat
# Processing Record 20 of Set 10 | lasa
# Processing Record 21 of Set 10 | adrar
# Processing Record 22 of Set 10 | menongue
# Processing Record 23 of Set 10 | waddan
# Processing Record 24 of Set 10 | poum
# Processing Record 25 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 10 | bang saphan
# Processing Record 27 of Set 10 | haines junction
# Processing Record 28 of Set 10 | blackwater
# Processing Record 29 of Set 10 | kungurtug
# Processing Record 30 of Set 10 | sapao
# City not found. Skipping...
# Processing Record 31 of Set 10 | kiunga
# Processing Record 32 of Set 10 | rapid valley
# Processing Record 33 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 10 | nylstroom
# City not found. Skipping...
# Processing Record 35 of Set 10 | gisenyi
# Processing Record 36 of Set 10 | gayny
# Processing Record 37 of Set 10 | aripuana
# Processing Record 38 of Set 10 | muravlenko
# Processing Record 39 of Set 10 | apatity
# Processing Record 40 of Set 10 | chiang klang
# Processing Record 41 of Set 10 | zyryanka
# Processing Record 42 of Set 10 | liwale
# Processing Record 43 of Set 10 | hofn
# Processing Record 44 of Set 10 | sabak
# Processing Record 45 of Set 10 | bambari
# Processing Record 46 of Set 10 | bucerias
# Processing Record 47 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 10 | haslett
# Processing Record 49 of Set 10 | muika
# City not found. Skipping...
# Processing Record 50 of Set 10 | solnechnyy
# Processing Record 1 of Set 11 | beloha
# Processing Record 2 of Set 11 | srandakan
# Processing Record 3 of Set 11 | shu
# Processing Record 4 of Set 11 | santa rosa
# Processing Record 5 of Set 11 | rincon
# Processing Record 6 of Set 11 | santa cruz
# Processing Record 7 of Set 11 | hasaki
# Processing Record 8 of Set 11 | nizwa
# Processing Record 9 of Set 11 | los llanos de aridane
# Processing Record 10 of Set 11 | panguna
# Processing Record 11 of Set 11 | keetmanshoop
# Processing Record 12 of Set 11 | whitehorse
# Processing Record 13 of Set 11 | jaisalmer
# Processing Record 14 of Set 11 | phangnga
# Processing Record 15 of Set 11 | tawang
# Processing Record 16 of Set 11 | tura
# Processing Record 17 of Set 11 | jiangkou
# Processing Record 18 of Set 11 | sitangkai
# Processing Record 19 of Set 11 | kralendijk
# Processing Record 20 of Set 11 | ontario
# Processing Record 21 of Set 11 | santa maria
# Processing Record 22 of Set 11 | sechura
# Processing Record 23 of Set 11 | manggar
# Processing Record 24 of Set 11 | maragogi
# Processing Record 25 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 11 | kibre mengist
# Processing Record 27 of Set 11 | muisne
# Processing Record 28 of Set 11 | kloulklubed
# Processing Record 29 of Set 11 | carman
# Processing Record 30 of Set 11 | sirjan
# Processing Record 31 of Set 11 | laja
# Processing Record 32 of Set 11 | grenada
# Processing Record 33 of Set 11 | bolshaya murta
# City not found. Skipping...
# Processing Record 34 of Set 11 | sungaipenuh
# Processing Record 35 of Set 11 | alyangula
# Processing Record 36 of Set 11 | high prairie
# Processing Record 37 of Set 11 | namatanai
# Processing Record 38 of Set 11 | lakatoro
# Processing Record 39 of Set 11 | bayshore gardens
# Processing Record 40 of Set 11 | viedma
# Processing Record 41 of Set 11 | arman
# Processing Record 42 of Set 11 | pucallpa
# Processing Record 43 of Set 11 | haapiti
# Processing Record 44 of Set 11 | yulara
# Processing Record 45 of Set 11 | dubbo
# Processing Record 46 of Set 11 | bubaque
# Processing Record 47 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 48 of Set 11 | akyab
# Processing Record 49 of Set 11 | nyuksenitsa
# Processing Record 50 of Set 11 | paamiut
# Processing Record 1 of Set 12 | manjo
# Processing Record 2 of Set 12 | cayenne
# Processing Record 3 of Set 12 | itarema
# Processing Record 4 of Set 12 | manama
# Processing Record 5 of Set 12 | albion
# Processing Record 6 of Set 12 | eureka
# Processing Record 7 of Set 12 | bayan
# Processing Record 8 of Set 12 | caravelas
# Processing Record 9 of Set 12 | praia da vitoria
# Processing Record 10 of Set 12 | kholodnyy
# Processing Record 11 of Set 12 | verkhnyaya inta
# Processing Record 12 of Set 12 | nicoya
# Processing Record 13 of Set 12 | tocantinopolis
# City not found. Skipping...
# Processing Record 14 of Set 12 | chengde
# Processing Record 15 of Set 12 | chinsali
# Processing Record 16 of Set 12 | suez
# Processing Record 17 of Set 12 | kisangani
# Processing Record 18 of Set 12 | kudahuvadhoo
# Processing Record 19 of Set 12 | atar
# Processing Record 20 of Set 12 | fairborn
# Processing Record 21 of Set 12 | taksimo
# Processing Record 22 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 23 of Set 12 | khammam
# Processing Record 24 of Set 12 | borzoy
# Processing Record 25 of Set 12 | morant bay
# Processing Record 26 of Set 12 | castro
# Processing Record 27 of Set 12 | portland
# Processing Record 28 of Set 12 | prestea
# Processing Record 29 of Set 12 | monrovia
# Processing Record 30 of Set 12 | alice springs
# Processing Record 31 of Set 12 | balakhta
# Processing Record 32 of Set 12 | marion
# Processing Record 33 of Set 12 | newport
# Processing Record 34 of Set 12 | inhambane
# Processing Record 35 of Set 12 | guiratinga
# Processing Record 36 of Set 12 | prince rupert
# Processing Record 37 of Set 12 | dovolnoye
# Processing Record 38 of Set 12 | mayo
# Processing Record 39 of Set 12 | castro alves
# Processing Record 40 of Set 12 | coruripe
# Processing Record 41 of Set 12 | kamyaran
# Processing Record 42 of Set 12 | punta alta
# Processing Record 43 of Set 12 | griffith
# Processing Record 44 of Set 12 | aguas formosas
# Processing Record 45 of Set 12 | scottsbluff
# Processing Record 46 of Set 12 | goundam
# Processing Record 47 of Set 12 | hutchinson
# Processing Record 48 of Set 12 | jiexiu
# Processing Record 49 of Set 12 | campo verde
# Processing Record 50 of Set 12 | glasgow
# Processing Record 1 of Set 13 | itupeva
# Processing Record 2 of Set 13 | eslamshahr
# Processing Record 3 of Set 13 | pathein
# Processing Record 4 of Set 13 | kargat
# Processing Record 5 of Set 13 | waipawa
# Processing Record 6 of Set 13 | ulladulla
# Processing Record 7 of Set 13 | montero
# Processing Record 8 of Set 13 | tacuarembo
# Processing Record 9 of Set 13 | umm lajj
# Processing Record 10 of Set 13 | revelstoke
# Processing Record 11 of Set 13 | lompoc
# Processing Record 12 of Set 13 | malindi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 562
# city found 562
# skipped record 50

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
#632 total cities times 9x data per city = 5688 entries
#41 not found cities times 9x data per city = 441 entries
#632 - 41 = 583 cities remaining (look index of data frame) = 5247 entries
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                   City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0              Batagay  67.63  134.63     -5.10        98         100
# 1         Punta Arenas -53.15  -70.92     51.80        87          35
# 2         Saint George  37.10 -113.58     51.80        27           1
# 3               Atuona  -9.80 -139.03     81.88        77         100
# 4    Placido De Castro -10.34  -67.19     72.63        99         100
# ..                 ...    ...     ...       ...       ...         ...
# 557         Tacuarembo -31.73  -55.98     46.13        90           0
# 558           Umm Lajj  25.02   37.27     73.69        20           0
# 559         Revelstoke  50.98 -118.20     28.40        86          90
# 560             Lompoc  34.64 -120.46     57.20        82          75
# 561            Malindi  -3.22   40.12     86.00        74          75
#
#      Wind Speed Country                 Date
# 0          1.95      RU  2020-02-22 08:29:14
# 1          5.82      CL  2020-02-22 08:27:54
# 2          5.82      US  2020-02-22 08:27:11
# 3         15.37      PF  2020-02-22 08:27:54
# 4          1.41      BR  2020-02-22 08:29:15
# ..          ...     ...                  ...
# 557        3.13      UY  2020-02-22 08:31:17
# 558        8.84      SA  2020-02-22 08:31:18
# 559        3.91      CA  2020-02-22 08:31:18
# 560        6.93      US  2020-02-22 08:31:18
# 561        6.93      KE  2020-02-22 08:31:18
#
# [562 rows x 9 columns]

# %%
#City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed
new_order =["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# %%
city_data_df = city_data_df[new_order]

# %%
city_data_df
# Out:
#                   City Country                 Date    Lat     Lng  Max Temp  \
# 0              Batagay      RU  2020-02-22 08:29:14  67.63  134.63     -5.10
# 1         Punta Arenas      CL  2020-02-22 08:27:54 -53.15  -70.92     51.80
# 2         Saint George      US  2020-02-22 08:27:11  37.10 -113.58     51.80
# 3               Atuona      PF  2020-02-22 08:27:54  -9.80 -139.03     81.88
# 4    Placido De Castro      BR  2020-02-22 08:29:15 -10.34  -67.19     72.63
# ..                 ...     ...                  ...    ...     ...       ...
# 557         Tacuarembo      UY  2020-02-22 08:31:17 -31.73  -55.98     46.13
# 558           Umm Lajj      SA  2020-02-22 08:31:18  25.02   37.27     73.69
# 559         Revelstoke      CA  2020-02-22 08:31:18  50.98 -118.20     28.40
# 560             Lompoc      US  2020-02-22 08:31:18  34.64 -120.46     57.20
# 561            Malindi      KE  2020-02-22 08:31:18  -3.22   40.12     86.00
#
#      Humidity  Cloudiness  Wind Speed
# 0          98         100        1.95
# 1          87          35        5.82
# 2          27           1        5.82
# 3          77         100       15.37
# 4          99         100        1.41
# ..        ...         ...         ...
# 557        90           0        3.13
# 558        20           0        8.84
# 559        86          90        3.91
# 560        82          75        6.93
# 561        74          75        6.93
#
# [562 rows x 9 columns]

# %%
# Create the output file (CSV).
import os

output_data_file = os.path.join("weather_data","cities.csv")

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%x")
today
# Out:
# '02/22/20'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")
#alpha parameter is the transparency level 0 is transparent 1 is not transparent

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ today)
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
